# %% [markdown]
# # FORD GO BIKE DATA ANALYSIS

# %% [markdown]
# ## Contents

# %% [markdown]
#     Introduction
#     Preliminary Wrangling
#     Univariate Exploration
#     Bivariate Exploration
#     Multivariate Exploration

# %% [markdown]
# ## Introduction
#
# In this project, we will be visualizing Ford [GoBike System Data](https://s3.amazonaws.com/fordgobike-data/index.html).This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.
#
# The Data includes following :
#
#     Trip Duration (seconds)
#     Start Time and Date
#     End Time and Date
#     Start Station ID
#     Start Station Name
#     Start Station Latitude
#     Start Station Longitude
#     End Station ID
#     End Station Name
#     End Station Latitude
#     End Station Longitude
#     Bike ID
#     User Type (Subscriber or Customer – “Subscriber” = Member or “Customer” = Casual)
#     Bike share for all trip
#     Member Year of Birth
#     Member Gender

# %% [markdown]
# ## Preliminary Wrangling

# %%
# import all packages 

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb 
import os
import glob 

# %matplotlib inline

# %% [markdown]
# ### Gathering Data

# %%
# Location where the csv files are stored
path = './Data'
files= glob.glob(os.path.join(path, "*.csv"))

# concatenate the data 
df = pd.concat((pd.read_csv(file, low_memory=False) for file in files), ignore_index = True, sort = True)

df.to_csv('bike_data_final.csv', index=False)

# %% [markdown]
# ### Assessing Data

# %%
df_bikes = pd.read_csv('bike_data_final.csv',low_memory= False)
df_bikes.head(10)
# Out:
#    bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 0     1035                      No           598           114.0
# 1     1673                      No           943           324.0
# 2     3498                      No         18587            15.0
# 3     3129                      No         18558            15.0
# 4     1839                     Yes           885           297.0
# 5     2656                      No           921           288.0
# 6     1616                      No           277           310.0
# 7      144                      No           285           196.0
# 8     3351                      No           363           189.0
# 9     1699                     Yes           226           327.0
#
#    end_station_latitude  end_station_longitude  \
# 0             37.764478            -122.402570
# 1             37.788300            -122.408531
# 2             37.795392            -122.394203
# 3             37.795392            -122.394203
# 4             37.322980            -121.887931
# 5             37.350964            -121.902016
# 6             37.335885            -121.885660
# 7             37.808894            -122.256460
# 8             37.839649            -122.271756
# 9             37.332039            -121.881766
#
#                                     end_station_name  \
# 0                         Rhode Island St at 17th St
# 1                Union Square (Powell St at Post St)
# 2  San Francisco Ferry Building (Harry Bridges Pl...
# 3  San Francisco Ferry Building (Harry Bridges Pl...
# 4                              Locust St at Grant St
# 5                               Mission St at 1st St
# 6                          San Fernando St at 4th St
# 7                            Grand Ave at Perkins St
# 8                                Genoa St at 55th St
# 9                          5th St at San Salvador St
#
#                    end_time  member_birth_year member_gender  \
# 0  2018-03-01 00:09:45.1870             1988.0          Male
# 1  2018-02-28 23:36:59.9740             1987.0          Male
# 2  2018-02-28 23:30:42.9250             1986.0        Female
# 3  2018-02-28 23:30:12.4500             1981.0          Male
# 4  2018-02-28 23:29:58.6080             1976.0        Female
# 5  2018-02-28 23:29:40.4370             1997.0          Male
# 6  2018-02-28 23:26:27.2220             1957.0        Female
# 7  2018-02-28 23:26:05.4050             1990.0        Female
# 8  2018-02-28 23:25:22.2740             1975.0          Male
# 9  2018-02-28 23:19:06.6200             1996.0          Male
#
#    start_station_id  start_station_latitude  start_station_longitude  \
# 0             284.0               37.784872              -122.400876
# 1               6.0               37.804770              -122.403234
# 2              93.0               37.770407              -122.391198
# 3              93.0               37.770407              -122.391198
# 4             308.0               37.336802              -121.894090
# 5             312.0               37.329732              -121.901782
# 6             316.0               37.330165              -121.885831
# 7             198.0               37.807813              -122.264496
# 8             176.0               37.828410              -122.266315
# 9             295.0               37.332794              -121.875926
#
#                                   start_station_name  \
# 0  Yerba Buena Center for the Arts (Howard St at ...
# 1                      The Embarcadero at Sansome St
# 2                       4th St at Mission Bay Blvd S
# 3                       4th St at Mission Bay Blvd S
# 4                                   San Pedro Square
# 5                           San Jose Diridon Station
# 6                          San Salvador St at 1st St
# 7                                          Snow Park
# 8                             MacArthur BART Station
# 9                              William St at 10th St
#
#                  start_time   user_type
# 0  2018-02-28 23:59:47.0970  Subscriber
# 1  2018-02-28 23:21:16.4950    Customer
# 2  2018-02-28 18:20:55.1900    Customer
# 3  2018-02-28 18:20:53.6210    Customer
# 4  2018-02-28 23:15:12.8580  Subscriber
# 5  2018-02-28 23:14:19.1700    Customer
# 6  2018-02-28 23:21:49.2740  Subscriber
# 7  2018-02-28 23:21:19.6310  Subscriber
# 8  2018-02-28 23:19:18.6060  Subscriber
# 9  2018-02-28 23:15:20.0330  Subscriber

# %%
# Get data rows x columns
df_bikes.shape
# Out:
# (3254325, 16)

# %%
# Get information abt data
df_bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3254325 entries, 0 to 3254324
# Data columns (total 16 columns):
# bike_id                    int64
# bike_share_for_all_trip    object
# duration_sec               int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name           object
# end_time                   object
# member_birth_year          float64
# member_gender              object
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name         object
# start_time                 object
# user_type                  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 397.3+ MB

# %%
# Get null data in each column
df_bikes.isnull().sum()
# Out:
# bike_id                         0
# bike_share_for_all_trip    519700
# duration_sec                    0
# end_station_id              12501
# end_station_latitude            0
# end_station_longitude           0
# end_station_name            12501
# end_time                        0
# member_birth_year          218166
# member_gender              217733
# start_station_id            12501
# start_station_latitude          0
# start_station_longitude         0
# start_station_name          12501
# start_time                      0
# user_type                       0
# dtype: int64

# %%
df_bikes.member_gender.value_counts()
# Out:
# Male      2251128
# Female     735690
# Other       49774
# Name: member_gender, dtype: int64

# %%
df_bikes.user_type.value_counts()
# Out:
# Subscriber    2747580
# Customer       506745
# Name: user_type, dtype: int64

# %%
df_bikes.bike_share_for_all_trip.value_counts()
# Out:
# No     2495879
# Yes     238746
# Name: bike_share_for_all_trip, dtype: int64

# %%
df_bikes.member_birth_year.value_counts()
# Out:
# 1988.0    174820
# 1987.0    148691
# 1989.0    148213
# 1990.0    141104
# 1985.0    136066
#            ...
# 1886.0         3
# 1906.0         2
# 1930.0         2
# 1903.0         1
# 1910.0         1
# Name: member_birth_year, Length: 93, dtype: int64

# %%
df_bikes.query('member_birth_year < 1900')['member_birth_year'].count()
# Out:
# 76

# %% [markdown]
# ### Quality Issues

# %% [markdown]
#    - String datatype for start_time and end_time instead datetime
#    - member_gender should be categorical data type insted of str
#    - member_gender should have only Male and Female category and others are invalid
#    - user_type should be categorical data type instead of str
#    - bike_share_for_all_trip should be categorical instead of str
#    - member_birth_year has data < 1900 causing age > 100 years
#
#    - Add new column for age
#    - Add a new column for age_group
#    - Add new column for trip day of the week and trip month of year

# %% [markdown]
# ### Clean Data

# %%
# Creating copy of data for cleaning
df_bikes_clean = df_bikes.copy()

# %% [markdown]
# ### Quality issue 1 : Data inconsistency in year

# %% [markdown]
# **Define** In member_birth_year, birth_year should be greater than 1920 as people with age > 100 can be removed.

# %%
df_bikes_clean = df_bikes[df_bikes.member_birth_year > 1920]

# %% [markdown]
# **Test**

# %%
df_bikes_clean.query('member_birth_year <= 1920')['member_birth_year'].count()
# Out:
# 0

# %% [markdown]
# ### Quality issue 2: New columns for age , age group ,day of week and month of year

# %% [markdown]
# **Define** Create age column for the member and remove records with age <70 and group into age

# %%
df_bikes_clean['age'] = pd.Timestamp('now').year - df_bikes_clean['member_birth_year']
df_bikes_clean['age'] = df_bikes_clean['age'].astype(int)

df_bikes_clean = df_bikes_clean[df_bikes_clean['age'] <=70]
# Out:
# /Users/aswathyn/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/aswathyn/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Generate a new field for member age group from member_age_bin
df_bikes_clean['age_group'] = df_bikes_clean['age'].apply(lambda x: '10 - 20' if 10<x<=20
                                                  else '20 - 30' if 20 < x <= 30
                                                  else '30 - 40' if 30 < x <= 40
                                                  else '40 - 50' if 40 < x <= 50
                                                  else '50 - 60' if 50 < x <= 60
                                                  else '60 - 70' if 60 < x <= 70
                                                  else x)
df_bikes_clean.age_group = df_bikes_clean.age_group.astype('category')

# %% [markdown]
# **Test**

# %%
df_bikes_clean.sample(10)
# Out:
#          bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 2667960      734                      No           197           239.0
# 2000551     2600                      No           575            66.0
# 218429      3727                      No           630            23.0
# 1785820     3822                      No           815           324.0
# 1096453      322                     NaN           901            11.0
# 2521383     1190                      No           306             9.0
# 2809960     3005                      No           404            89.0
# 2578717     3131                      No          1726           158.0
# 216493       500                      No           720            50.0
# 553269      4058                     Yes           965            86.0
#
#          end_station_latitude  end_station_longitude  \
# 2667960             37.868813            -122.258764
# 2000551             37.778742            -122.392741
# 218429              37.791464            -122.391034
# 1785820             37.788300            -122.408531
# 1096453             37.797280            -122.398436
# 2521383             37.798572            -122.400869
# 2809960             37.769218            -122.407646
# 2578717             37.833279            -122.263490
# 216493              37.780526            -122.390288
# 553269              37.769305            -122.426826
#
#                             end_station_name                  end_time  \
# 2667960        Bancroft Way at Telegraph Ave  2018-10-25 10:16:02.9870
# 2000551                3rd St at Townsend St  2018-01-17 08:34:47.3100
# 218429         The Embarcadero at Steuart St  2018-11-05 05:50:10.2250
# 1785820  Union Square (Powell St at Post St)  2018-05-06 15:07:35.5090
# 1096453               Davis St at Jackson St  2017-08-18 07:24:26.3420
# 2521383               Broadway at Battery St  2018-08-17 16:05:03.6880
# 2809960           Division St at Potrero Ave  2018-10-03 14:21:10.8060
# 2578717        Shattuck Ave at Telegraph Ave  2018-08-08 17:43:32.6040
# 216493                 2nd St at Townsend St  2018-11-05 09:16:06.1420
# 553269               Market St at Dolores St  2018-09-19 15:18:04.6400
#
#          member_birth_year member_gender  start_station_id  \
# 2667960             1997.0          Male             253.0
# 2000551             1973.0        Female              16.0
# 218429              1974.0          Male              91.0
# 1785820             1976.0          Male              99.0
# 1096453             1956.0          Male              30.0
# 2521383             1960.0          Male              15.0
# 2809960             1984.0          Male              97.0
# 2578717             1974.0        Female             187.0
# 216493              1986.0        Female               6.0
# 553269              1988.0          Male              52.0
#
#          start_station_latitude  start_station_longitude  \
# 2667960               37.866418              -122.253799
# 2000551               37.794130              -122.394430
# 218429                37.771762              -122.398438
# 1785820               37.767037              -122.415442
# 1096453               37.776598              -122.395282
# 2521383               37.795392              -122.394203
# 2809960               37.768265              -122.420110
# 2578717               37.796248              -122.279352
# 216493                37.804770              -122.403234
# 553269                37.777416              -122.441838
#
#                                         start_station_name  \
# 2667960                            Haste St at College Ave
# 2000551                            Steuart St at Market St
# 218429                                 Berry St at King St
# 1785820                               Folsom St at 15th St
# 1096453     San Francisco Caltrain (Townsend St at 4th St)
# 2521383  San Francisco Ferry Building (Harry Bridges Pl...
# 2809960                              14th St at Mission St
# 2578717                                 Jack London Square
# 216493                       The Embarcadero at Sansome St
# 553269                           McAllister St at Baker St
#
#                        start_time   user_type  age age_group
# 2667960  2018-10-25 10:12:45.7070    Customer   23   20 - 30
# 2000551  2018-01-17 08:25:11.7310  Subscriber   47   40 - 50
# 218429   2018-11-05 05:39:40.2240  Subscriber   46   40 - 50
# 1785820  2018-05-06 14:53:59.6120    Customer   44   40 - 50
# 1096453  2017-08-18 07:09:24.5680  Subscriber   64   60 - 70
# 2521383  2018-08-17 15:59:56.8570  Subscriber   60   50 - 60
# 2809960  2018-10-03 14:14:26.1260  Subscriber   36   30 - 40
# 2578717  2018-08-08 17:14:46.5850    Customer   46   40 - 50
# 216493   2018-11-05 09:04:05.5750  Subscriber   34   30 - 40
# 553269   2018-09-19 15:01:59.1840  Subscriber   32   30 - 40

# %%
df_bikes_clean.age.value_counts()
# Out:
# 32    174820
# 33    148691
# 31    148213
# 30    141104
# 35    136066
# 29    134661
# 27    134034
# 34    132740
# 36    123118
# 28    120616
# 37    113100
# 26    108996
# 38    107987
# 25     92363
# 39     86347
# 40     86143
# 41     68333
# 43     63913
# 42     61940
# 24     61326
# 45     56721
# 44     49881
# 46     49662
# 47     44522
# 23     44137
# 52     42074
# 49     41946
# 48     37839
# 55     36694
# 50     34946
# 22     34944
# 51     32124
# 53     29508
# 57     25847
# 21     25183
# 56     22946
# 58     21641
# 54     21466
# 59     19143
# 60     15985
# 61     14574
# 62     13612
# 20     12543
# 63     10820
# 64      9751
# 66      7531
# 68      5095
# 65      4799
# 70      3547
# 67      3288
# 69      3201
# 19       267
# Name: age, dtype: int64

# %% [markdown]
# ### Quality issue 3:  Wrong data type

# %% [markdown]
# **Define** : Change datatypes for start_time, end_time, member_gender, user_type, bike_share_for_all_trip.
#
# member_gender should have only Male and Female, Others are marked as None

# %%
# Fixing data type for start_time and end_time
df_bikes_clean.start_time = pd.to_datetime(df_bikes_clean['start_time'],format="%Y-%m-%d %H:%M:%S.%f")
df_bikes_clean.end_time = pd.to_datetime(df_bikes_clean['end_time'],format="%Y-%m-%d %H:%M:%S.%f")

# Updating invalid gender types as None
df_bikes_clean.loc[(df_bikes_clean.member_gender == 'Other'), 'member_gender'] = None 

# Changing data type for member_gender, user_type, bike_share_for_all_trip to category
df_bikes_clean.member_gender = df_bikes_clean.member_gender.astype('category')
df_bikes_clean.user_type = df_bikes_clean.user_type.astype('category')
df_bikes_clean.bike_share_for_all_trip = df_bikes_clean.bike_share_for_all_trip.astype('category')

# %% [markdown]
# **Test**

# %%
df_bikes_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3020748 entries, 0 to 3254324
# Data columns (total 18 columns):
# bike_id                    int64
# bike_share_for_all_trip    category
# duration_sec               int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name           object
# end_time                   datetime64[ns]
# member_birth_year          float64
# member_gender              category
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name         object
# start_time                 datetime64[ns]
# user_type                  category
# age                        int64
# age_group                  category
# dtypes: category(4), datetime64[ns](2), float64(7), int64(3), object(2)
# memory usage: 357.2+ MB

# %%
df_bikes_clean.member_gender.value_counts()
# Out:
# Male      2238206
# Female     733418
# Name: member_gender, dtype: int64

# %% [markdown]
# **Define** Extract and create day of week , month of year and hour of the day from start time

# %%
# Extract month from start time
df_bikes_clean['trip_month'] = df_bikes_clean['start_time'].dt.strftime('%B')

# Extract day of week from start time
df_bikes_clean['trip_weekday'] = df_bikes_clean['start_time'].dt.strftime('%a')

# Extract month-year from start time
df_bikes_clean['year_month']=df_bikes_clean['start_time'].map(lambda x: x.strftime('%Y-%m'))

# Extract start time hour
df_bikes_clean['start_hour']=df_bikes_clean['start_time'].dt.hour

# %% [markdown]
# **Test**

# %%
df_bikes_clean.sample(10)
# Out:
#          bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 2722709     3694                      No           271           252.0
# 1649185       32                     Yes          1212            49.0
# 3103694     5172                      No          1273           337.0
# 1334511      681                      No          1027            37.0
# 1003747     2632                     NaN           333           174.0
# 1354387     4060                      No           267            50.0
# 1622562     5935                      No           155            58.0
# 2161487     5522                      No           611            15.0
# 2988690     3176                      No           513            43.0
# 995788      1943                     NaN           261           120.0
#
#          end_station_latitude  end_station_longitude  \
# 2722709             37.865847            -122.267443
# 1649185             37.780760            -122.394989
# 3103694             37.806970            -122.266588
# 1334511             37.785000            -122.395936
# 1003747             37.836801            -122.264004
# 1354387             37.780526            -122.390288
# 1622562             37.776619            -122.417385
# 2161487             37.795392            -122.394203
# 2988690             37.778768            -122.415929
# 995788              37.761420            -122.426435
#
#                                           end_station_name  \
# 2722709                       Channing Way at Shattuck Ave
# 1649185                                S Park St at 3rd St
# 3103694                              Webster St at 19th St
# 1334511                                2nd St at Folsom St
# 1003747                            Shattuck Ave at 51st St
# 1354387                              2nd St at Townsend St
# 1622562                               Market St at 10th St
# 2161487  San Francisco Ferry Building (Harry Bridges Pl...
# 2988690  San Francisco Public Library (Grove St at Hyde...
# 995788                                Mission Dolores Park
#
#                        end_time  member_birth_year member_gender  ...  \
# 2722709 2018-10-16 21:52:33.602             1988.0          Male  ...
# 1649185 2018-05-30 11:47:22.026             1979.0        Female  ...
# 3103694 2019-02-24 13:43:06.196             1984.0        Female  ...
# 1334511 2018-06-08 08:54:09.895             1977.0          Male  ...
# 1003747 2017-09-17 19:32:39.921             1988.0          Male  ...
# 1354387 2018-06-05 14:58:36.108             1971.0          Male  ...
# 1622562 2019-03-03 19:20:21.279             1990.0        Female  ...
# 2161487 2019-01-15 07:17:59.442             1964.0          Male  ...
# 2988690 2018-04-20 18:34:12.372             1995.0        Female  ...
# 995788  2017-09-19 22:12:15.586             1994.0          Male  ...
#
#          start_station_longitude            start_station_name  \
# 2722709              -122.254337   Bancroft Way at College Ave
# 1649185              -122.411403                  Precita Park
# 3103694              -122.273970          Webster St at 2nd St
# 1334511              -122.398773            Jackson Playground
# 1003747              -122.271756           Genoa St at 55th St
# 1354387              -122.391198  4th St at Mission Bay Blvd S
# 1622562              -122.411306           Howard St at 8th St
# 2161487              -122.393170            Berry St at 4th St
# 2988690              -122.426244         Laguna St at Hayes St
# 995788               -122.426614         Dolores St at 15th St
#
#                      start_time   user_type age age_group  trip_month  \
# 2722709 2018-10-16 21:48:01.702    Customer  32   30 - 40     October
# 1649185 2018-05-30 11:27:09.852  Subscriber  41   40 - 50         May
# 3103694 2019-02-24 13:21:53.147  Subscriber  36   30 - 40    February
# 1334511 2018-06-08 08:37:02.805    Customer  43   40 - 50        June
# 1003747 2017-09-17 19:27:06.641  Subscriber  32   30 - 40   September
# 1354387 2018-06-05 14:54:08.662  Subscriber  49   40 - 50        June
# 1622562 2019-03-03 19:17:45.445  Subscriber  30   20 - 30       March
# 2161487 2019-01-15 07:07:48.307  Subscriber  56   50 - 60     January
# 2988690 2018-04-20 18:25:39.172  Subscriber  25   20 - 30       April
# 995788  2017-09-19 22:07:54.028  Subscriber  26   20 - 30   September
#
#         trip_weekday year_month start_hour
# 2722709          Tue    2018-10         21
# 1649185          Wed    2018-05         11
# 3103694          Sun    2019-02         13
# 1334511          Fri    2018-06          8
# 1003747          Sun    2017-09         19
# 1354387          Tue    2018-06         14
# 1622562          Sun    2019-03         19
# 2161487          Tue    2019-01          7
# 2988690          Fri    2018-04         18
# 995788           Tue    2017-09         22
#
# [10 rows x 22 columns]

# %% [markdown]
# ## What is the structure of the dataset ?

# %% [markdown]
# Dataset has around 3M + bike rides over a span of 2017, 2018 and 2019 with features like bike_id, member_age, member_gender,start_time, end_time, user_type, duration_sec etc.

# %% [markdown]
# ## What are the main features of interest in your dataset?¶

# %% [markdown]
#     - What is the average duration of a trip
#     - How trip duration varies on day of the week and month of the year
#     - Does user_type, gender and age has any effects on trip duration

# %% [markdown]
# ## What features in the dataset do you think will help support your investigation into your features of interest?¶

# %% [markdown]
# Gender, age group, day of the week, user type and trip duration

# %% [markdown]
# ## Univariate Exploration

# %% [markdown]
# > In univariate exploration, individual variables distribution is analysed.

# %% [markdown]
# **user_type distribution**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
_ = sb.countplot(data = df_bikes_clean, x = 'user_type', color = base_color)

plt.xlabel('User type');
plt.ylabel('Total rides');
plt.title('Distribution on User type');

# %% [markdown]
#  > The distribution clearly shows majority of bike ride users are subscribers.

# %% [markdown]
# **member_gender distribution**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
_ = sb.countplot(data = df_bikes_clean, x = 'member_gender', color = base_color)

plt.xlabel('Gender');
plt.ylabel('Total rides');
plt.title('Distribution on Gender');

# %% [markdown]
# > The distribution clearly shows majority of bike ride users are Male.

# %% [markdown]
# **bike_share_for_all_trip distribution**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
_ = sb.countplot(data = df_bikes_clean, x = 'bike_share_for_all_trip', color = base_color)

plt.xlabel('Bike share');
plt.ylabel('Total rides');
plt.title('Distribution on Bike share');

# %% [markdown]
# > People use Ford goBikes for part of the trip. They rarely use bike share

# %% [markdown]
# **Age distribution**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
plt.hist(data = df_bikes_clean, x = 'age');
plt.xlabel('Member Age');
plt.ylabel('Total rides');
plt.title('Age distribution on Bike Ride');

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
_ = sb.boxplot(data = df_bikes_clean, x = 'age', color = base_color);
plt.xlabel('Member Age');
plt.title('Age distribution on Bike Ride');

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
_ = sb.countplot(data = df_bikes_clean, x = 'age_group', color = base_color);
plt.xlabel('Age Group');
plt.title('Age Group on Bike Ride');

# %% [markdown]
# > Distribution clearly shows major subscribers belong to age group 30 -40

# %% [markdown]
# **Trip duration distribution**

# %%
bins_edge = np.arange(0, df_bikes_clean.duration_sec.max()+100, 100)

plt.hist(data=df_bikes_clean, x='duration_sec', bins=bins_edge)
plt.xlim(0, 2000)
plt.xlabel('Duration (sec)');
plt.ylabel('Frequency');
plt.title('Trip duration distribution');

# %% [markdown]
# > Distribution is skewed right and clearly shows most of the trips have duration of 300 - 700 seconds.

# %% [markdown]
# **Distribution by start hour**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
sb.countplot(data=df_bikes_clean, x='start_hour',color=base_color);
plt.xlabel('Trip start hour');
plt.ylabel('Total rides');
plt.title('Ford GoBike usage by Hour of day');

# %% [markdown]
# > Distribution indicates 8- 9 AM and 5-6 PM is the peak hours for the ride.

# %% [markdown]
# **Distribution on Day of Week usage**

# %%
fig = plt.figure()
base_color = sb.color_palette()[0]
day_order = ['Sun','Mon','Tue','Wed','Thu','Fri','Sat']
sb.countplot(data=df_bikes_clean, x='trip_weekday',order = day_order,color=base_color);
plt.xlabel('Day of Week');
plt.ylabel('Total rides');
plt.title('Ford GoBike usage by Day of Week');

# %% [markdown]
# > Distribution clearly indicates weekdays have more rides than weekends. Also ride usage is more towards the middle of week.

# %% [markdown]
# **Distribution on month_year usage**

# %%
fig = plt.figure(figsize=(14,8))
base_color = sb.color_palette()[0]
sb.countplot(data=df_bikes_clean.sort_values(by='year_month'), x='year_month',color = base_color);
plt.xlabel('Year - Month',fontsize = 12);
plt.ylabel('Total rides', fontsize = 12);
plt.title('Ford GoBike usage by Year-Month');
plt.xticks(rotation=45);

# %% [markdown]
# > Distribution shows an upward trend in usage of Ford GoBike and adoption rate has increased from 2017 - 2019.

# %% [markdown]
# **Distribution on monthly usage**

# %%
fig = plt.figure(figsize=(14,8))
base_color = sb.color_palette()[0]
order = reversed(df_bikes_clean['trip_month'].value_counts().index)

sb.countplot(data = df_bikes_clean, x = 'trip_month',color = base_color,order = order);
plt.xlabel('Month',fontsize = 14);
plt.ylabel('Total rides', fontsize = 14);
plt.title('Ford GoBike usage by Month',fontsize = 14);
plt.xticks(rotation=45);

# %% [markdown]
# > Distribution shows the usage is more during March - April

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# > In this section , relationships between pairs of variables are analysed.

# %%
df_bikes_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3020748 entries, 0 to 3254324
# Data columns (total 22 columns):
# bike_id                    int64
# bike_share_for_all_trip    category
# duration_sec               int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name           object
# end_time                   datetime64[ns]
# member_birth_year          float64
# member_gender              category
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name         object
# start_time                 datetime64[ns]
# user_type                  category
# age                        int64
# age_group                  category
# trip_month                 object
# trip_weekday               object
# year_month                 object
# start_hour                 int64
# dtypes: category(4), datetime64[ns](2), float64(7), int64(4), object(5)
# memory usage: 449.4+ MB

# %%
df_bikes_clean['trip_month'] = df_bikes_clean['trip_month'].astype('category')
df_bikes_clean['trip_weekday'] = df_bikes_clean['trip_weekday'].astype('category')
df_bikes_clean['year_month']=df_bikes_clean['year_month'].astype('category')
df_bikes_clean['start_hour']=df_bikes_clean['start_hour'].astype('category')

# %%
df_bikes_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3020748 entries, 0 to 3254324
# Data columns (total 22 columns):
# bike_id                    int64
# bike_share_for_all_trip    category
# duration_sec               int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name           object
# end_time                   datetime64[ns]
# member_birth_year          float64
# member_gender              category
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name         object
# start_time                 datetime64[ns]
# user_type                  category
# age                        int64
# age_group                  category
# trip_month                 category
# trip_weekday               category
# year_month                 category
# start_hour                 category
# dtypes: category(8), datetime64[ns](2), float64(7), int64(3), object(2)
# memory usage: 368.7+ MB

# %% [markdown]
# > Lets analyse the impact of categorical variables - bike_share_for_all_trip, member_gender, age_group, user_type, trip_month, trip_weekday and start_hour on **duration_sec**

# %%
#Plotting bike_share_for_all_trip vs duration _sec

def plots(x_value, x_label):
    plt.figure(figsize = [8, 6])
    base_color = sb.color_palette()[0]
    sb.boxplot(data = df_bikes_clean, x = x_value, y = 'duration_sec', color = base_color)
    plt.ylim(0, 2000);
    plt.xlabel(x_label,fontsize = 12);
    plt.ylabel('Total Duration (sec)', fontsize = 14);
    plt.title(x_label +' vs duration (sec)',fontsize = 14);
    plt.xticks(rotation=45)

# %%
plots('bike_share_for_all_trip','Bike share all trip')

# %%
plots('member_gender','Member Gender')

# %%
plots('user_type','User Type')

# %% [markdown]
# > Customers tends to ride more time compared to subscribers

# %%
plots('start_hour', 'Trip Start Hour')

# %%
plots('trip_weekday', 'Day of Week')

# %%
plt.figure(figsize = [12, 6]);
sb.pointplot(x="trip_weekday", y="duration_sec",data=df_bikes_clean);
plt.ylim(0, 2000);
plt.xlabel('Trip Day',fontsize = 12);
plt.ylabel('Total Duration (sec)', fontsize = 14);
plt.title('Day of week vs Duration (sec)',fontsize = 14);
plt.xticks(rotation=45);

# %% [markdown]
# > Distribution shows trip duration tend to be more during weekends compared to weekdays.

# %%
plots('trip_month','Month of year')

# %% [markdown]
# > Duration of trips looks same for all the months

# %%
plots('age_group','Age Group')

# %%
plt.figure(figsize = [20, 10]);
base_color = sb.color_palette()[0]
sb.pointplot(x="year_month", y="duration_sec",data=df_bikes_clean,color=base_color);
plt.xticks(rotation = 90);
plt.xlabel("Year-Month",fontsize = 14);
plt.ylabel("Duration (sec)",fontsize = 14);
plt.title("Year-Month vs Duration (sec) distribution");

# %% [markdown]
# > Distribution shows there was high duration trip during 2017 and later got reduced.Ford Go bikes was introduced in June 2017 so the initial times, the duration of trips were more which got reduced later.

# %%
df_bikes_clean['start_station_name'].value_counts()
# Out:
# San Francisco Caltrain Station 2  (Townsend St at 4th St)    63712
# Market St at 10th St                                         60665
# San Francisco Ferry Building (Harry Bridges Plaza)           57358
# San Francisco Caltrain (Townsend St at 4th St)               56836
# Berry St at 4th St                                           55371
#                                                              ...
# Sonora Ave at 1st St                                            14
# Auzerais Ave at Los Gatos Creek Trail                           10
# 17th St at Santa Clara St                                        8
# Delmas Ave at Virginia St                                        5
# SF Test Station                                                  1
# Name: start_station_name, Length: 393, dtype: int64

# %%
top_station = df_bikes_clean['start_station_name'].value_counts().index[:5]
df_station = df_bikes_clean.loc[df_bikes_clean['start_station_name'].isin(top_station)]

plt.figure(figsize = [13, 8])

sb.boxplot(data = df_station, x = 'start_station_name', y = 'duration_sec', palette = 'Blues')
plt.ylim(0, 2000);
plt.xticks(rotation = 45);
plt.xlabel("Station Name",fontsize = 14);
plt.ylabel("Duration (sec)",fontsize = 14);
plt.title("Station vs Duration (sec) distribution",fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Station vs Duration (sec) distribution')

# %% [markdown]
# > From top 5 stations where users having maximum start trip registered, we can see that San Francisco Ferry Building has trips having maximum duration recordered with an average of 650 seconds

# %% [markdown]
# ## Multivariate Exploration

# %% [markdown]
# > In this section we create plots of three or more variables to analyse data. We will analyse how age_group, weekdays and duration_sec relationship.

# %%
plt.figure(figsize=[20, 8])

plt.subplot(1, 2, 1)
sb.pointplot(data=df_bikes_clean, x='year_month', y='duration_sec', hue='user_type', palette= 'viridis')
plt.xticks(rotation=90);
plt.ylim(0, 3000);
plt.xlabel('Year Month',fontsize = 14);
plt.title('Usertype vs Duration (sec) for Year month');
plt.ylabel('Duration',fontsize = 14);

plt.subplot(1, 2, 2)
sb.pointplot(data=df_bikes_clean, x='year_month', y='duration_sec', hue='member_gender', palette='viridis')
plt.xticks(rotation=90);
plt.ylim(0, 3000);
plt.xlabel('Year Month',fontsize = 14);
plt.ylabel('Duration',fontsize = 14);
plt.title('Gender vs Duration (sec) for Year month');

# %% [markdown]
# > From distribution , it shows duration is consistent across subscribers while customers had
# a higher trip duration during early 2017 which gradually declined. Ford gobikes was launched in 2017 June
# and initial promotions/ offers may be the reason for lengthy duration for customers.
#
# > From Gender distribution against duration_sec over the years shows Females ride longer duration over males.

# %%
plt.figure(figsize = [30, 26]);
day_order = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
g = sb.FacetGrid(data = df_bikes_clean, col = 'age_group',col_wrap = 2,height = 4,palette = 'Set1', aspect=2.5);
g.map(sb.boxplot, 'trip_weekday', 'duration_sec',order = day_order).fig.subplots_adjust(wspace=.2, hspace=.2);
plt.ylim(0,3000);

# %% [markdown]
# ## Summary

# %% [markdown]
# Based on the analysis of GoBike data for the years 2017 - 2019 following are the conclusions
#
# Maximum rentals are seen with subscribers of Ford Go bike and out of which majority of riders are males.
#
# Rider age distribution shows 30 -40 yrs are using rental more than any other age group.
# Maximum rental happens during weekdays among subscriber between morning 8 -9 AM and evening 5-7 PM, while customers tend to use more during weekends.
#
# Duration of the ride shows customer tend to ride more time than subscribers though time duration shows negative slide. Weekends duration of ride is more though number of people availing ride is less compared to weekday
#
# SanFrancisco Caltrain Station 2  has maximum number of starting trip while SanFrancisco Ferry Building has
# trips with maximum duration.
#
# Older age group tend to use ride during non-peak hours.
